# %% [markdown]
# <a href="https://colab.research.google.com/github/sivakumar41/Hand-gesture-recognition/blob/main/hand_gesture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install mediapipe
#!pip install tensorflow
import cv2                                   #Here Im Importing the necessary libraries All the nedded ones for the
import numpy as np                            # Hand gesture recognition
import mediapipe as mp
import tensorflow as tf
from tensorflow.keras.models import load_model

# %%
# initialize mediapipe
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mpDraw = mp.solutions.drawing_utils

# %%
# Load the gesture recognizer model
model = load_model('/content/mp_hand_gesture')

# %%
# Load class names
f = open('gesture.names', 'r')
classNames = f.read().split('\n')
f.close()
print(classNames)
# Out:
# ['okay', 'peace', 'thumbs up', 'thumbs down', 'call me', 'stop', 'rock', 'live long', 'fist', 'smile']

# %%
from google.colab import files
uploaded = files.upload()

# Read the uploaded image                        #the camera is not working in the colab due the server crash issue. To work on the idle all module are not
file_name = next(iter(uploaded))                  #supporting so im using files module to upload the specific file and running them
frame = cv2.imread(file_name)
# Out:
#      <input type="file" id="files-ec7498ed-49ad-4fcf-93ab-59bfdd49f4c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec7498ed-49ad-4fcf-93ab-59bfdd49f4c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
x, y, c = frame.shape
frame = cv2.flip(frame, 1)
framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
result = hands.process(framergb)
className = ''
if result.multi_hand_landmarks:
  landmarks = []
  for handslms in result.multi_hand_landmarks:
    for lm in handslms.landmark:

      lmx = int(lm.x * x)
      lmy = int(lm.y * y)

      landmarks.append([lmx, lmy])
      mpDraw.draw_landmarks(frame, handslms, mpHands.HAND_CONNECTIONS)

    prediction = model.predict([landmarks])
    classID = np.argmax(prediction)
    className = classNames[classID]

cv2.putText(frame, className, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv2.LINE_AA)

# Show the final output
#cv2.imshow("Output", frame)   #it is notworking in the colab that y im using the matplolib for showing the image
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(frame)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 54ms/step

# %%
from google.colab.patches import cv2_imshow

# %%
from google.colab import files
uploaded = files.upload()

# Read the uploaded image                        #the camera is not working in the colab due the server crash issue. To work on the idle all module are not
file_name = next(iter(uploaded))                  #supporting so im using files module to upload the specific file and running them
frame = cv2.imread(file_name)
# Out:
#      <input type="file" id="files-8b1511a1-3564-47a5-9487-bb7124093cd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b1511a1-3564-47a5-9487-bb7124093cd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
x, y, c = frame.shape
frame = cv2.flip(frame, 1)
framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
result = hands.process(framergb)
className = ''
if result.multi_hand_landmarks:
  landmarks = []
  for handslms in result.multi_hand_landmarks:
    for lm in handslms.landmark:

      lmx = int(lm.x * x)
      lmy = int(lm.y * y)

      landmarks.append([lmx, lmy])
      mpDraw.draw_landmarks(frame, handslms, mpHands.HAND_CONNECTIONS)

    prediction = model.predict([landmarks])
    classID = np.argmax(prediction)
    className = classNames[classID]

cv2.putText(frame, className, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv2.LINE_AA)

# Show the final output
#cv2.imshow("Output", frame)   #it is notworking in the colab that y im using the matplolib for showing the image
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(frame)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
from google.colab import files
uploaded = files.upload()

# Read the uploaded image                        #the camera is not working in the colab due the server crash issue. To work on the idle all module are not
file_name = next(iter(uploaded))                  #supporting so im using files module to upload the specific file and running them
frame = cv2.imread(file_name)
# Out:
#      <input type="file" id="files-5bb4e958-d968-4a2c-9cd6-e762c3c75c0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bb4e958-d968-4a2c-9cd6-e762c3c75c0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
x, y, c = frame.shape
frame = cv2.flip(frame, 1)
framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
result = hands.process(framergb)
className = ''
if result.multi_hand_landmarks:
  landmarks = []
  for handslms in result.multi_hand_landmarks:
    for lm in handslms.landmark:

      lmx = int(lm.x * x)
      lmy = int(lm.y * y)

      landmarks.append([lmx, lmy])
      mpDraw.draw_landmarks(frame, handslms, mpHands.HAND_CONNECTIONS)

    prediction = model.predict([landmarks])
    classID = np.argmax(prediction)
    className = classNames[classID]

cv2.putText(frame, className, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv2.LINE_AA)

# Show the final output
#cv2.imshow("Output", frame)   #it is notworking in the colab that y im using the matplolib for showing the image
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(frame)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
# Out:
# Failed to open the webcam.
